# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
sns.set_palette("Set2")

# %%
df = pd.read_csv("college_placement_1000.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("college_placement_1000.csv")
#       2 df.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'college_placement_1000.csv'

# %%
df.shape
df.info()
df.describe()

# %%
df.isnull().sum()

# %%
df.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.nunique()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(7,4))
sns.histplot(df["cgpa"], kde=True)
plt.title("CGPA Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 plt.figure(figsize=(7,4))
# ----> 2 sns.histplot(df["cgpa"], kde=True)
#       3 plt.title("CGPA Distribution")
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.countplot(data=df, x="internships")
plt.title("Internships Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.countplot(data=df, x="internships")
#       2 plt.title("Internships Distribution")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.histplot(df["technical_score"], kde=True)
plt.title("Technical Score Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.histplot(df["technical_score"], kde=True)
#       2 plt.title("Technical Score Distribution")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.countplot(data=df, x="placed")
plt.title("Placement Distribution (0 = Not Placed, 1 = Placed)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.countplot(data=df, x="placed")
#       2 plt.title("Placement Distribution (0 = Not Placed, 1 = Placed)")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(7,4))
sns.boxplot(data=df, x="placed", y="cgpa")
plt.title("CGPA vs Placement Status")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 plt.figure(figsize=(7,4))
# ----> 2 sns.boxplot(data=df, x="placed", y="cgpa")
#       3 plt.title("CGPA vs Placement Status")
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.barplot(x="internships", y="placed", data=df)
plt.title("Internships vs Placement")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.barplot(x="internships", y="placed", data=df)
#       2 plt.title("Internships vs Placement")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.barplot(x="projects", y="placed", data=df)
plt.title("Projects vs Placement")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.barplot(x="projects", y="placed", data=df)
#       2 plt.title("Projects vs Placement")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.barplot(x="certifications", y="placed", data=df)
plt.title("Certifications vs Placement")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.barplot(x="certifications", y="placed", data=df)
#       2 plt.title("Certifications vs Placement")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(x="placed", y="communication_score", data=df)
plt.title("Communication Score vs Placement")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.boxplot(x="placed", y="communication_score", data=df)
#       2 plt.title("Communication Score vs Placement")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(x="placed", y="aptitude_score", data=df)
plt.title("Aptitude Score vs Placement")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sns.boxplot(x="placed", y="aptitude_score", data=df)
#       2 plt.title("Aptitude Score vs Placement")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(x="placed", y="technical_score", data=df)
plt.title("Technical Score vs Placement")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.boxplot(x="placed", y="technical_score", data=df)
#       2 plt.title("Technical Score vs Placement")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
domain_placement = df.groupby("domain")["placed"].mean().sort_values()

plt.figure(figsize=(10,4))
domain_placement.plot(kind="bar")
plt.title("Placement Rate by Domain")
plt.ylabel("Placement Probability")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 domain_placement = df.groupby("domain")["placed"].mean().sort_values()
#       3 plt.figure(figsize=(10,4))
#       4 domain_placement.plot(kind="bar")
#
# NameError: name 'df' is not defined

# %%
df["skills"].value_counts().head(10).plot(kind="bar", figsize=(10,4))
plt.title("Most Common Skill Combinations")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df["skills"].value_counts().head(10).plot(kind="bar", figsize=(10,4))
#       2 plt.title("Most Common Skill Combinations")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
#       3 plt.title("Correlation Heatmap")
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
print("Average CGPA of Placed Students:", df[df.placed==1]["cgpa"].mean())
print("Average CGPA of Not Placed Students:", df[df.placed==0]["cgpa"].mean())

print("\nTop Domains with Highest Placement Probability:")
print(domain_placement.sort_values(ascending=False).head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print("Average CGPA of Placed Students:", df[df.placed==1]["cgpa"].mean())
#       2 print("Average CGPA of Not Placed Students:", df[df.placed==0]["cgpa"].mean())
#       4 print("\nTop Domains with Highest Placement Probability:")
#
# NameError: name 'df' is not defined
